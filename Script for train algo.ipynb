# %% [markdown]
# # Script for training the algorithm

# %%
# %%bash
# # Setting up the email address
# git config --global user.name "Rajanikant"
# git config --global user.email "rajanikantdevmore@outlook.com"

# %%
# %%bash
# # Downloading the git repo
# git clone https://github.com/prodevans/user-registration-ai.git
# Out:
# Cloning into 'user-registration-ai'...
# Checking out files: 100% (4044/4044), done.

# %%
# %%bash
# # Changing the directory
# cd user-registration-ai/src/
#
# # Traing the algorithm
# bash train.sh
# Out:
# 2018-09-11 06:52:59.530326: W tensorflow/core/framework/op_def_util.cc:346] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# ERROR:tensorflow:Image directory '' not found.
# Traceback (most recent call last):
#   File "/opt/rh/rh-python35/root/usr/lib64/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/rh/rh-python35/root/usr/lib64/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/opt/app-root/src/workspace/user-registration-ai/src/scripts/retrain.py", line 1326, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/opt/app-root/lib/python3.5/site-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "/opt/app-root/src/workspace/user-registration-ai/src/scripts/retrain.py", line 989, in main
#     class_count = len(image_lists.keys())
# ...

# %%
# %%bash
# pwd
# # Changing the directory
# cd user-registration-ai/
#
# # Commit the code
# git add -A
# git commit -m 'trained algo'
#
# # Push code into repository
# git push
# Out:
# /opt/app-root/src/workspace
# # On branch master
# nothing to commit, working directory clean
# ...
# Git 2.0 from 'matching' to 'simple'. To squelch this message
# and maintain the current behavior after the default changes, use:
#
#   git config --global push.default matching
#
# To squelch this message and adopt the new behavior now, use:
#
#   git config --global push.default simple
#
# See 'git help config' and search for 'push.default' for further information.
# (the 'simple' mode was introduced in Git 1.7.11. Use the similar mode
# 'current' instead of 'simple' if you sometimes use older versions of Git)
#
# Everything up-to-date
